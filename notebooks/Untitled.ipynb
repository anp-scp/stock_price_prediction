# %%
import stockstats as st
import numpy as np
import pandas as pd

# %%
stock = st.StockDataFrame.retype(pd.read_csv('/home/anupam/stockPrediction/data/^BSESN (2).csv'))

# %%
stock.head(10)
# Out:
#                     open          high           low         close  \
# date
# 2016-06-29  26627.150391  26776.169922  26606.310547  26740.390625
# 2016-06-30  26926.169922  27069.230469  26872.589844  26999.720703
# 2016-07-01  27064.330078  27243.359375  27061.400391  27144.910156
# 2016-07-04  27314.439453  27385.660156  27251.060547  27278.759766
# 2016-07-05  27340.720703  27348.660156  27127.300781  27166.869141
# 2016-07-07  27209.970703  27288.220703  27146.949219  27201.490234
# 2016-07-08  27292.199219  27294.820313  27034.140625  27126.900391
# 2016-07-11  27358.230469  27647.480469  27358.230469  27626.689453
# 2016-07-12  27667.810547  27828.740234  27667.810547  27808.140625
# 2016-07-13  27912.140625  27928.759766  27752.140625  27815.179688
#
#                adj close  volume
# date
# 2016-06-29  26740.390625    7700
# 2016-06-30  26999.720703    8600
# 2016-07-01  27144.910156   10000
# 2016-07-04  27278.759766    8300
# 2016-07-05  27166.869141   10400
# ...

# %%
stock.head()
# Out:
#                     open          high           low         close  \
# date
# 2016-06-29  26627.150391  26776.169922  26606.310547  26740.390625
# 2016-06-30  26926.169922  27069.230469  26872.589844  26999.720703
# 2016-07-01  27064.330078  27243.359375  27061.400391  27144.910156
# 2016-07-04  27314.439453  27385.660156  27251.060547  27278.759766
# 2016-07-05  27340.720703  27348.660156  27127.300781  27166.869141
#
#                adj close  volume
# date
# 2016-06-29  26740.390625    7700
# 2016-06-30  26999.720703    8600
# 2016-07-01  27144.910156   10000
# 2016-07-04  27278.759766    8300
# 2016-07-05  27166.869141   10400

# %%
import matplotlib.pyplot as plt
from matplotlib import style
style.use('ggplot')

# %%
plt.figure(figsize=(20,10))
plt.plot(stock['macds'][:100])
plt.plot(stock['macd'][:100])
plt.fill_between(stock.index[:100],stock['macdh'][:100],color='grey',label="MACD histogram")
plt.legend(fontsize=20)
plt.xlabel("Date")
plt.ylabel("Values")
plt.xticks(rotation=90)
plt.show()
