# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dfTrain = pd.read_csv("train.csv",header=0)
dfTest = pd.read_csv("test.csv",header=0)
yTest = pd.read_csv("sample_submission.csv",header=0)

# %%
dfTrain.head(2)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0      2   2008        WD         Normal     208500
# 1      5   2007        WD         Normal     181500
#
# [2 rows x 81 columns]

# %%
dfTrain = dfTrain.set_index("Id")
dfTest = dfTest.set_index("Id")
yTest = yTest.set_index("Id")

# %%
for col in dfTrain.columns[dfTrain.isna().any()].tolist():
    if(dfTrain[col].dtype == "object"):
        dfTrain[col].fillna("unknown", inplace=True)
    if((dfTrain[col].dtype == "float64") or (dfTrain[col].dtype == "int64")):
        dfTrain[col].fillna(dfTrain[col].mean(), inplace=True)
for col in dfTest.columns[dfTest.isna().any()].tolist():
    if(dfTest[col].dtype == "object"):
        dfTest[col].fillna("unknown", inplace=True)
    if((dfTest[col].dtype == "float64") or (dfTest[col].dtype == "int64")):
        dfTest[col].fillna(dfTest[col].mean(), inplace=True)

# %%
dfTrain = dfTrain.select_dtypes(include=[np.number])
dfTest = dfTest.select_dtypes(include=[np.number])

# %%
df_corr = abs(pd.DataFrame(dfTrain.corr()['SalePrice']))
df_corr.sort_values('SalePrice',ascending=False)
# Out:
#                SalePrice
# SalePrice       1.000000
# OverallQual     0.790982
# GrLivArea       0.708624
# GarageCars      0.640409
# GarageArea      0.623431
# TotalBsmtSF     0.613581
# 1stFlrSF        0.605852
# FullBath        0.560664
# TotRmsAbvGrd    0.533723
# YearBuilt       0.522897
# YearRemodAdd    0.507101
# MasVnrArea      0.475241
# GarageYrBlt     0.470177
# Fireplaces      0.466929
# BsmtFinSF1      0.386420
# LotFrontage     0.334901
# WoodDeckSF      0.324413
# 2ndFlrSF        0.319334
# OpenPorchSF     0.315856
# HalfBath        0.284108
# LotArea         0.263843
# BsmtFullBath    0.227122
# BsmtUnfSF       0.214479
# BedroomAbvGr    0.168213
# KitchenAbvGr    0.135907
# EnclosedPorch   0.128578
# ScreenPorch     0.111447
# PoolArea        0.092404
# MSSubClass      0.084284
# OverallCond     0.077856
# MoSold          0.046432
# 3SsnPorch       0.044584
# YrSold          0.028923
# LowQualFinSF    0.025606
# MiscVal         0.021190
# BsmtHalfBath    0.016844
# BsmtFinSF2      0.011378

# %%
dfTrain = dfTrain.drop(['3SsnPorch', 'BsmtFinSF2', 'BsmtHalfBath', 'MoSold', 'MiscVal'], axis=1)
dfTest = dfTest.drop(['3SsnPorch', 'BsmtFinSF2', 'BsmtHalfBath', 'MoSold', 'MiscVal'], axis=1)

# %%
df_corr = abs(pd.DataFrame(dfTrain.corr()['SalePrice']))
df_corr.sort_values('SalePrice',ascending=False)
# Out:
#                SalePrice
# SalePrice       1.000000
# OverallQual     0.790982
# GrLivArea       0.708624
# GarageCars      0.640409
# GarageArea      0.623431
# TotalBsmtSF     0.613581
# 1stFlrSF        0.605852
# FullBath        0.560664
# TotRmsAbvGrd    0.533723
# YearBuilt       0.522897
# YearRemodAdd    0.507101
# MasVnrArea      0.475241
# GarageYrBlt     0.470177
# Fireplaces      0.466929
# BsmtFinSF1      0.386420
# LotFrontage     0.334901
# WoodDeckSF      0.324413
# 2ndFlrSF        0.319334
# OpenPorchSF     0.315856
# HalfBath        0.284108
# LotArea         0.263843
# BsmtFullBath    0.227122
# BsmtUnfSF       0.214479
# BedroomAbvGr    0.168213
# KitchenAbvGr    0.135907
# EnclosedPorch   0.128578
# ScreenPorch     0.111447
# PoolArea        0.092404
# MSSubClass      0.084284
# OverallCond     0.077856
# YrSold          0.028923
# LowQualFinSF    0.025606

# %%
dfTrain.head()
# Out:
#     MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# Id
# 1           60         65.0     8450            7            5       2003
# 2           20         80.0     9600            6            8       1976
# 3           60         68.0    11250            7            5       2001
# 4           70         60.0     9550            7            5       1915
# 5           60         84.0    14260            8            5       2000
#
#     YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtUnfSF    ...      GarageYrBlt  \
# Id                                                     ...
# 1           2003       196.0         706        150    ...           2003.0
# 2           1976         0.0         978        284    ...           1976.0
# 3           2002       162.0         486        434    ...           2001.0
# 4           1970         0.0         216        540    ...           1998.0
# 5           2000       350.0         655        490    ...           2000.0
#
#     GarageCars  GarageArea  WoodDeckSF  OpenPorchSF  EnclosedPorch  \
# Id
# 1            2         548           0           61              0
# 2            2         460         298            0              0
# 3            2         608           0           42              0
# 4            3         642           0           35            272
# 5            3         836         192           84              0
#
#     ScreenPorch  PoolArea  YrSold  SalePrice
# Id
# 1             0         0    2008     208500
# 2             0         0    2007     181500
# 3             0         0    2008     223500
# 4             0         0    2006     140000
# 5             0         0    2008     250000
#
# [5 rows x 32 columns]

# %%
XTrain = dfTrain.drop(['SalePrice'],1)
yTrain = np.array(dfTrain['SalePrice'])
XTest = dfTest
yTest = np.array(yTest['SalePrice'])

# %%
XTrain.head()
# Out:
#     MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# Id
# 1           60         65.0     8450            7            5       2003
# 2           20         80.0     9600            6            8       1976
# 3           60         68.0    11250            7            5       2001
# 4           70         60.0     9550            7            5       1915
# 5           60         84.0    14260            8            5       2000
#
#     YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtUnfSF   ...    Fireplaces  \
# Id                                                    ...
# 1           2003       196.0         706        150   ...             0
# 2           1976         0.0         978        284   ...             1
# 3           2002       162.0         486        434   ...             1
# 4           1970         0.0         216        540   ...             1
# 5           2000       350.0         655        490   ...             1
#
#     GarageYrBlt  GarageCars  GarageArea  WoodDeckSF  OpenPorchSF  \
# Id
# 1        2003.0           2         548           0           61
# 2        1976.0           2         460         298            0
# 3        2001.0           2         608           0           42
# 4        1998.0           3         642           0           35
# 5        2000.0           3         836         192           84
#
#     EnclosedPorch  ScreenPorch  PoolArea  YrSold
# Id
# 1               0            0         0    2008
# 2               0            0         0    2007
# 3               0            0         0    2008
# 4             272            0         0    2006
# 5               0            0         0    2008
#
# [5 rows x 31 columns]

# %%
from sklearn.preprocessing import scale
XTrainScaled = scale(XTrain)
XTestScaled = scale(XTest)
# XTrainScaled = np.array(XTrain)
# XTestScaled = np.array(XTest)

# %%
from sklearn import svm
clf = svm.SVR(C=0.1,epsilon=2,gamma=0.3)
clf = svm.SVR()
clf.fit(XTrainScaled,yTrain)
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
from sklearn.metrics import accuracy_score
yPrdeict = clf.predict(XTestScaled)
r2 = clf.score(XTest,yPrdeict)
r2_train = clf.score(XTrain,yTrain)

# for i in range(50):
#     print("ytest:{}  ypredict:{}".format(yTest[i],yPrdeict[i]))
r2_train
# Out:
# -0.05083183918335732
